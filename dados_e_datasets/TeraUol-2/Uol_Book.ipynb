# %% [markdown]
# ### Crawler obtido do site https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7434436/
#
#
# ### Este notebook foi adaptado para coletar informações do site "TercaLivre.com.br para nosso trabalho"
#
# Palavras-chave: Tratamento, COVID-19, Pandemia

# %%
import os
import requests

# %% [markdown]
# ## 1a. Parte: Buscando os dados do site

# %%
#Place where the files will be saved
dir_output = 'pages'

# %%
# Procedure to create a directory to save the pages
try:
    os.mkdir(dir_output)
except OSError:
    print ("Directory %s already exists." % dir_output)
else:
    print ("Successfully created the directory %s " % dir_output)
# Out:
# Directory pages already exists.

# %%
#List of URLs gathered manually
input_file = "TeraUol-links.txt"

# %%
#url

# %% [markdown]
# Fazendo a coleta de dados

# %%
from time import sleep
from random import randint
pages_collected = next(os.walk(dir_output))[2]
with open(input_file) as infile:
    for line in infile:
        url = line.strip()
        page_name = url.split('/')[-1]
        if page_name in pages_collected:
            print ("Page already collected.")
            continue
        elif page_name.split('.')[-1] != "htm":
            print ("Link is not a pageLink não é uma página HTML")
            continue
        print (url)
        print('Conte até dez...')
        sleep(randint(1,15))
        page = requests.get(url)

        with open(dir_output + '/' + page_name, 'w') as f:
            f.write(page.text)
# Out:
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/20/com-lupus-elas-temem-falta-de-cloroquina-dores-podem-voltar-mais-fortes.htm
# Conte até dez...
# Page already collected.
# https://noticias.uol.com.br/ultimas-noticias/afp/2020/06/01/o-mundo-dividido-sobre-o-uso-da-hidroxicloroquina.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/confere/ultimas-noticias/2020/03/24/coronavirus-o-que-e-verdadeiro-e-o-que-e-falso-sobre-a-cloroquina.htm
# Conte até dez...
# Page already collected.
# https://noticias.uol.com.br/ultimas-noticias/reuters/2020/06/02/trump-e-bolsonaro-discutiram-esforco-conjunto-sobre-uso-da-hidroxicloroquina-contra-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://economia.uol.com.br/noticias/bloomberg/2020/03/16/coronavirus-ricos-aliviam-ansiedade-com-kit-de-emergencia-de-us-4995.htm
# Conte até dez...
# https://noticias.uol.com.br/ultimas-noticias/agencia-brasil/2020/03/23/cientistas-uruguaios-desenvolvem-kit-de-diagnostico-para-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/videos/2020/03/25/ministerio-libera-cloroquina-para-casos-graves-0402CD193572DCB96326.htm
# Conte até dez...
# https://noticias.uol.com.br/colunas/diogo-schelp/2020/06/01/convenios-que-adotaram-cloroquina-esvaziaram-seus-ctis-diz-nise-yamaguchi.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/noticias/bbc/2020/03/26/coronavirus-testes-com-cloroquina-causam-corrida-a-hospitais-discordancias-entre-medicos-na-franca.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://economia.uol.com.br/noticias/redacao/2020/03/26/vivara-vai-distribuir-10-mil-kits-de-higiene-por-conta-do-novo-coronavirus.htm
# Conte até dez...
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/06/02/bolsonaro-volta-a-defender-cloroquina-quem-reclama-de-alternativa.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/23/coronavirus-brasil-inicia-teste-com-hidroxicloroquina-estudo-leva-2-meses.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/24/coronavirus-homem-nos-eua-morre-apos-se-automedicar-com-cloroquina.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://entretenimento.uol.com.br/noticias/redacao/2020/03/27/grafiteiro-mundano-cria-kit-contra-o-coronavirus-para-catadores-de-rua.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/23/prevent-senior-usa-cloroquina-em-todos-os-pacientes-com-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/19/cloroquina-o-que-se-sabe-sobre-remedio-que-pode-tratar-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/reuters/2020/06/02/lancet-diz-ter-preocupacao-com-validade-de-dados-de-estudo-com-cloroquina.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://www.uol.com.br/vivabem/noticias/bbc/2020/06/03/com-cloroquina-desaconselhada-por-cientistas-veja-outras-apostas-de-tratamento.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/25/coronavirus-ministerio-anuncia-que-vai-aplicar-cloroquina-em-casos-graves.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/25/cloroquina-cuidados-basicos-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/06/02/coletiva-ministerio-da-saude-cloroquina-coronavirus.htm
# Conte até dez...
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.
# Page already collected.

# %% [markdown]
# ## 2a. Parte: Criando as variáveis e atribuindo valores

# %%
import glob
import os
from bs4 import BeautifulSoup
import codecs
import datetime
import json
import csv

# %%
input_file = "TeraUol-links.txt"

# %% [markdown]
# ###   Procedure to get the list of pages collected previously

# %%
d = {}
with open(input_file) as infile:
    for line in set(infile):
        url = line.strip()
        page_name = url.split('/')[-1]
        day = line.strip().split('/')[-2]
        month = line.strip().split('/')[-3]
        year = line.strip().split('/')[-4]
        try:
            data_page = datetime.datetime.strptime(day + '-' + month + '-' + year, '%d-%m-%Y')
        except:
            None
        if data_page.month > 5 or  data_page.year < 2020:
            None
        else:
            d[page_name] = [url, str(data_page)]

# %% [markdown]
# ### Procedure to create a structure (d) with the data collected

# %%
dir_input = 'pages'
pages_collected = next(os.walk(dir_input))[2]
for page in pages_collected:
    if not page in d.keys():
        continue
    text_uol = []
    soup = BeautifulSoup(open(dir_input + '/' + page), "html.parser")
    divTag = soup.find_all("div", {"class": "text"})
    for tag in divTag:
        tdTags = tag.find_all("p")
        for tag in tdTags:
            if len(tag.text) < 10:
                continue
            text_uol.append(tag.text)
    d[page].append(text_uol)

# %%
#d

# %% [markdown]
# ### Procedure to save the data into file uol.csv

# %%
header = ['date', 'title', 'url', 'text']
with open("Tera_Uol.csv", "w", newline='') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(header) # write the header
    content = []
    for k,v in d.items():
        if len(v) == 2:
            continue
        url = v[0]
        title = url.split('/')[-1].split('.')[0].replace('-', ' ')
        data_page = v[1]
        text_uol = v[2]
        line = data_page, title, url, text_uol
        content.append(line)
    # write the actual content line by line
    newL = sorted(content, key=lambda x: x[0], reverse=False)
    for l in newL:
        writer.writerow(l)

# %% [markdown]
# # Procedimento para abri os dados do Tera_Uol.csv

# %%
#### ABRINDO O ARQUIVO CSV CRIADO: COPIAR O MESMO NOME DO NOVO CSV ####
import pandas as pd
df = pd.read_csv('Tera_Uol.csv', )

# %% [markdown]
# Lembrar que o header aqui é date - title - url - text
#
# == df.date ====== df.titulo ===== df.url ====== df.text ==

# %%
df.text
# Out:
# 0       ['A Fiocruz (Fundação Oswaldo Cruz) começou ho...
# 1       ['Alguns norte-americanos encontraram certa se...
# 2       ['A notícia de que Donald Trump pediu pressa p...
# 3       ['Após Donald Trump, presidente dos Estados Un...
# 4       ['A Agência Nacional de Vigilância Sanitária (...
#                               ...
# 1595    ['Da cabeça à ponta dos pés, passando pelos pu...
# 1596    ['Como o coronavírus se espalha facilmente ent...
# 1597    ['"Paciência" é a palavra que Heloísa Schurman...
# 1598    ['Da cabeça à ponta dos pés, passando pelos pu...
# 1599    ['Economistas de instituições financeiras cons...
# Name: text, Length: 1600, dtype: object
